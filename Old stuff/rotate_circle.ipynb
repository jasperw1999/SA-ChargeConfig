# %%
import numpy as np
from plot_params import *
from scipy.spatial.distance import cdist

# %%
# generate particles
n = 100
r = np.random.rand(n)
theta = np.random.rand(n) * 2 * np.pi
x = np.cos(theta) * r
y = np.sin(theta) * r
pos = np.stack((x, y), axis=1)

# plot them on a circle 
pos = np.stack((x, y), axis=1)
plt.figure(figsize=(6, 6))
plt.scatter(pos[:, 0], pos[:, 1])
circle = plt.Circle((0, 0), 1, fill=False)
plt.gca().add_patch(circle)

# %%
def rotation(pos, theta_rotation):
    # get polar coordinates
    x = pos[:, 0]
    y = pos[:, 1]
    r = np.sqrt(x ** 2 + y ** 2)
    theta = np.arctan2(y, x)

    # add an angle
    theta = theta + theta_rotation

    # back to cartesian
    x = np.cos(theta) * r
    y = np.sin(theta) * r
    pos = np.stack((x, y), axis=1)

    return pos

def difference_score(theta_rotation, standard_pos, pos):
    # rotate
    pos = rotation(pos, theta_rotation)

    # return distance score
    return cdist(standard_pos, pos).min(axis=1).sum()

def get_minimized_config(standard_pos, pos, precision=1000):

    radians = np.linspace(0, 2 * np.pi, precision)
    scores = [difference_score(r, standard_pos, pos) for r in radians]
    best_radian = radians[np.argmin(scores)]
    return rotation(pos, best_radian)

# %%
# create a bunch of perturbed versions of the original configuration

standard_pos = pos
perturbed_pos = []

for _ in range(10):
    theta = np.random.rand() * 2 * np.pi
    offset = np.random.rand(n, 2) * 0.01
    p = rotation(standard_pos, theta) + offset
    perturbed_pos.append(p)

plt.figure(figsize=(6, 6))
for p in perturbed_pos:
    plt.scatter(p[:, 0], p[:, 1])
circle = plt.Circle((0, 0), 1, fill=False)
plt.gca().add_patch(circle)
plt.scatter(standard_pos[:, 0], standard_pos[:, 1], s=400, zorder=-100)
plt.show()

# %%
plt.figure(figsize=(6, 6))
for p in perturbed_pos:
    plot_p = get_minimized_config(standard_pos, p)
    plt.scatter(plot_p[:, 0], plot_p[:, 1])
plt.scatter(standard_pos[:, 0], standard_pos[:, 1], s=500, zorder=-100)
circle = plt.Circle((0, 0), 1, fill=False)
plt.gca().add_patch(circle)
plt.show()

# %%
def total_energy(pos):
    dist = cdist(pos, pos)
    li = np.tril_indices(len(pos), k=-1)
    pair_dist = dist[li]
    total_energy = (1 / pair_dist).sum()
    return total_energy

# %%
all_pos = np.load('best.npy')

# fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# for ax, p in zip(axs, all_pos):
#     ax.scatter(p[:, 0], p[:, 1])

quality = []
for r in all_pos:
    q = total_energy(r)
    quality.append(q)

standard_pos = all_pos[np.argmin(quality)]
standard_pos = all_pos[0]

plt.figure(figsize=(6, 6))
for p in all_pos:
    plot_p = get_minimized_config(standard_pos, p)
    plt.scatter(plot_p[:, 0], plot_p[:, 1], color='tab:blue', edgecolors='darkslategray')
plt.scatter(standard_pos[:, 0], standard_pos[:, 1], s=500, zorder=-100, color='tab:orange')
circle = plt.Circle((0, 0), 1, fill=False)
plt.gca().add_patch(circle)
plt.yticks(np.linspace(-1, 1, 5))
plt.tight_layout()
# plt.savefig('figures/metric_example_007630.pdf')
plt.show()

# %%
# n_angles = 36000
# scores = np.zeros(n_angles)
# angles = np.linspace(0, 2 * np.pi, n_angles)

# for i, a in enumerate(angles):
#     scores[i] = difference_score(a, all_pos[0], all_pos[2])

# plt.plot(angles, scores)
# plt.show()

# %%
def getal(n):
    return n * (n-1)/2

plt.plot(range(10), getal(range(10)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29076/576841559.py in <module>
#       2     return n * (n-1)/2
#       3
# ----> 4 plt.plot(range(10), getal(range(10)))
#
# ~\AppData\Local\Temp/ipykernel_29076/576841559.py in getal(n)
#       1 def getal(n):
# ----> 2     return n * (n-1)/2
#       3
#       4 plt.plot(range(10), getal(range(10)))
#
# TypeError: unsupported operand type(s) for -: 'range' and 'int'

# %%
mean_list = []
for ap in all_pos:
    optimalized_configs = [get_minimized_config(ap, p) for p in all_pos]
    difference_scores = [difference_score(0, ap, p) for p in optimalized_configs]
    mean_list.append(np.mean(difference_scores))
np.mean(mean_list)
# Out:
# 0.11949131996292373
